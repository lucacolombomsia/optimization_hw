# %%
from pulp import *

# %%
# Create the 'prob' variable to contain the problem data
prob = LpProblem("Beer and Ale",LpMaximize)

# The 2 variables Ale and Beer are created with a lower limit of 0 and no upper limit
# They are LpContinuous variables
A=LpVariable("Ale",0,None,LpContinuous)
B=LpVariable("Beer",0,None, LpContinuous)

# The objective function is added to 'prob' first
prob += 13*A + 23*B, "Total Revenue of Production Plan"

# The three constraints are entered
prob += 5*A + 15*B <= 480, "Corn"
prob += 4*A + 4*B <= 160, "Hops"
prob += 35*A + 20*B <= 1190, "Malt"

# The problem data is written to an .lp file
prob.writeLP("BeerAle.lp")

# The problem is solved using PuLP's choice of Solver
prob.solve()

# The status of the solution is printed to the screen
print("Status:", LpStatus[prob.status])

# Each of the variables is printed with it's resolved optimum value
for v in prob.variables():
    print(v.name, "=", v.varValue)
    
# The optimised objective function value is printed to the screen
print("Total Revenue of Plan = ", value(prob.objective))

for constraint in prob.constraints:
        # print(prob.constraints[constraint].name, prob.constraints[constraint].value() - prob.constraints[constraint].constant)
        print(prob.constraints[constraint].name, prob.constraints[constraint].value())
        print(prob.constraints[constraint].name, prob.constraints[constraint].constant)
# Out:
# Status: Optimal
# Ale = 12.0
# Beer = 28.0
# Total Revenue of Plan =  800.0
# Corn 0.0
# Corn -480
# Hops 0.0
# Hops -160
# Malt -210.0
# Malt -1190

# %%
# This model separates the data from the optimization model
# We want to keep them separate, so that we can easily run the model multiple times with different input data

#Create a list of all the products
Products = ["Ale","Beer"]

#Create a dictionary of the prices for products
Prices = {"Ale": 13,
         "Beer":23}

#Create a list of all the raw materials
RawMaterials = ["Corn","Hops","Malt"]

#Create a Dictionary of Amount of each Raw Material Available
RawAvailability = {"Corn": 480,
                  "Hops": 160,
                  "Malt": 1190}

#Create a list for amount used of each raw material for each product
AmountUsed = {"Ale": {"Corn": 5, "Hops": 4, "Malt": 35},
              "Beer":{"Corn": 15, "Hops": 4, "Malt": 20}
             }

# Create the 'prob' variable to contain the problem data
prob = LpProblem("Beer and Ale",LpMaximize)

# Create the Variables
product_vars = LpVariable.dicts("Prods",Products,lowBound=0,upBound=None,cat=LpContinuous)

# The objective function is added to 'prob' first
prob += lpSum([Prices[i]*product_vars[i] for i in Products]), "Total Revenue of Production Plan"

# We can enter the constraints that relate to limited amount of material
for r in RawMaterials:
    prob += lpSum([product_vars[i]*AmountUsed[i][r] for i in Products]) <= RawAvailability[r]

# The problem data is written to an .lp file
prob.writeLP("BeerAle.lp")

# The problem is solved using PuLP's choice of Solver
prob.solve()

# The status of the solution is printed to the screen
print("Status:", LpStatus[prob.status])

# Each of the variables is printed with it's resolved optimum value
for v in prob.variables():
    print(v.name, "=", v.varValue)
    
# The optimised objective function value is printed to the screen
print("Total Revenue of Plan = ", value(prob.objective))

for constraint in prob.constraints:
        # print(prob.constraints[constraint].name, prob.constraints[constraint].value() - prob.constraints[constraint].constant)
        print(prob.constraints[constraint].name, prob.constraints[constraint].value())
        print(prob.constraints[constraint].name, prob.constraints[constraint].constant)
# Out:
# Status: Optimal
# Prods_Ale = 12.0
# Prods_Beer = 28.0
# Total Revenue of Plan =  800.0
# None 0.0
# None -480
# None 0.0
# None -160
# None -210.0
# None -1190

# %%
# This is a simple version to test different values
# We are running 100 different combinations

for x in range(0,101):


    # Create the 'prob' variable to contain the problem data
    prob = LpProblem("Beer and Ale",LpMaximize)

    # The 2 variables Ale and Beer are created with a lower limit of 0
    A=LpVariable("Ale",0,None,LpContinuous)
    B=LpVariable("Beer",0,None, LpContinuous)


    #Different Amounts of Raw Material Bought  Toggle the "+x" off or on to test different variables.
    Corn = 480 + x
    Hops = 160 + 0
    Malt = 1190 + 0
    

    # The objective function is added to 'prob' first
    prob += (13*A + 23*B), "Total Revenue"

    # The three constraints are entered
    prob += 5*A + 15*B <= Corn, "Corn"
    prob += 4*A + 4*B <= Hops, "Hops"
    prob += 35*A + 20*B <= Malt, "Malt"

    # The problem data is written to an .lp file
    prob.writeLP("BeerAle.lp")

    # The problem is solved using PuLP's choice of Solver
    prob.solve()

    # The status of the solution is printed to the screen
    print("---------------------")
    print("Status:", LpStatus[prob.status])

    # Each of the variables is printed with it's resolved optimum value
    for v in prob.variables():
        print(v.name, "=", v.varValue)

    # The optimised objective function value is printed to the screen
    print("Total Objective Value = ", value(prob.objective))

    #Actual total profit.  NOTE:  The profit changed here too....
    #print("Real Total Profit",25*A.varValue+10*B.varValue)  

    #Total Barrels
    print("Total Barrels Made",A.varValue+B.varValue)
    print ("Corn", Corn)
    print ("Hops",Hops)
    print ("Malt",Malt)
# Out:
# ---------------------
# Status: Optimal
# Ale = 12.0
# Beer = 28.0
# Total Objective Value =  800.0
# Total Barrels Made 40.0
# Corn 480
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 11.9
# Beer = 28.1
# Total Objective Value =  801.0000000000001
# Total Barrels Made 40.0
# Corn 481
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 11.8
# Beer = 28.2
# Total Objective Value =  802.0
# Total Barrels Made 40.0
# Corn 482
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 11.7
# Beer = 28.3
# Total Objective Value =  803.0
# Total Barrels Made 40.0
# Corn 483
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 11.6
# Beer = 28.4
# Total Objective Value =  803.9999999999999
# Total Barrels Made 40.0
# Corn 484
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 11.5
# Beer = 28.5
# Total Objective Value =  805.0
# Total Barrels Made 40.0
# Corn 485
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 11.4
# Beer = 28.6
# Total Objective Value =  806.0000000000001
# Total Barrels Made 40.0
# Corn 486
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 11.3
# Beer = 28.7
# Total Objective Value =  807.0
# Total Barrels Made 40.0
# Corn 487
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 11.2
# Beer = 28.8
# Total Objective Value =  808.0
# Total Barrels Made 40.0
# Corn 488
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 11.1
# Beer = 28.9
# Total Objective Value =  808.9999999999999
# Total Barrels Made 40.0
# Corn 489
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 11.0
# Beer = 29.0
# Total Objective Value =  810.0
# Total Barrels Made 40.0
# Corn 490
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 10.9
# Beer = 29.1
# Total Objective Value =  811.0000000000001
# Total Barrels Made 40.0
# Corn 491
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 10.8
# Beer = 29.2
# Total Objective Value =  812.0
# Total Barrels Made 40.0
# Corn 492
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 10.7
# Beer = 29.3
# Total Objective Value =  813.0
# Total Barrels Made 40.0
# Corn 493
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 10.6
# Beer = 29.4
# Total Objective Value =  813.9999999999999
# Total Barrels Made 40.0
# Corn 494
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 10.5
# Beer = 29.5
# Total Objective Value =  815.0
# Total Barrels Made 40.0
# Corn 495
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 10.4
# Beer = 29.6
# Total Objective Value =  816.0000000000001
# Total Barrels Made 40.0
# Corn 496
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 10.3
# Beer = 29.7
# Total Objective Value =  817.0
# Total Barrels Made 40.0
# Corn 497
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 10.2
# Beer = 29.8
# Total Objective Value =  818.0
# Total Barrels Made 40.0
# Corn 498
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 10.1
# Beer = 29.9
# Total Objective Value =  818.9999999999999
# Total Barrels Made 40.0
# Corn 499
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 10.0
# Beer = 30.0
# Total Objective Value =  820.0
# Total Barrels Made 40.0
# Corn 500
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 9.9
# Beer = 30.1
# Total Objective Value =  821.0000000000001
# Total Barrels Made 40.0
# Corn 501
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 9.8
# Beer = 30.2
# Total Objective Value =  822.0
# Total Barrels Made 40.0
# Corn 502
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 9.7
# Beer = 30.3
# Total Objective Value =  823.0
# Total Barrels Made 40.0
# Corn 503
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 9.6
# Beer = 30.4
# Total Objective Value =  823.9999999999999
# Total Barrels Made 40.0
# Corn 504
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 9.5
# Beer = 30.5
# Total Objective Value =  825.0
# Total Barrels Made 40.0
# Corn 505
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 9.4
# Beer = 30.6
# Total Objective Value =  826.0000000000001
# Total Barrels Made 40.0
# Corn 506
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 9.3
# Beer = 30.7
# Total Objective Value =  827.0
# Total Barrels Made 40.0
# Corn 507
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 9.2
# Beer = 30.8
# Total Objective Value =  828.0
# Total Barrels Made 40.0
# Corn 508
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 9.1
# Beer = 30.9
# Total Objective Value =  828.9999999999999
# Total Barrels Made 40.0
# Corn 509
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 9.0
# Beer = 31.0
# Total Objective Value =  830.0
# Total Barrels Made 40.0
# Corn 510
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 8.9
# Beer = 31.1
# Total Objective Value =  831.0000000000001
# Total Barrels Made 40.0
# Corn 511
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 8.8
# Beer = 31.2
# Total Objective Value =  832.0
# Total Barrels Made 40.0
# Corn 512
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 8.7
# Beer = 31.3
# Total Objective Value =  833.0
# Total Barrels Made 40.0
# Corn 513
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 8.6
# Beer = 31.4
# Total Objective Value =  833.9999999999999
# Total Barrels Made 40.0
# Corn 514
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 8.5
# Beer = 31.5
# Total Objective Value =  835.0
# Total Barrels Made 40.0
# Corn 515
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 8.4
# Beer = 31.6
# Total Objective Value =  836.0000000000001
# Total Barrels Made 40.0
# Corn 516
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 8.3
# Beer = 31.7
# Total Objective Value =  837.0
# Total Barrels Made 40.0
# Corn 517
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 8.2
# Beer = 31.8
# Total Objective Value =  838.0
# Total Barrels Made 40.0
# Corn 518
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 8.1
# Beer = 31.9
# Total Objective Value =  838.9999999999999
# Total Barrels Made 40.0
# Corn 519
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 8.0
# Beer = 32.0
# Total Objective Value =  840.0
# Total Barrels Made 40.0
# Corn 520
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 7.9
# Beer = 32.1
# Total Objective Value =  841.0000000000001
# Total Barrels Made 40.0
# Corn 521
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 7.8
# Beer = 32.2
# Total Objective Value =  842.0
# Total Barrels Made 40.0
# Corn 522
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 7.7
# Beer = 32.3
# Total Objective Value =  843.0
# Total Barrels Made 40.0
# Corn 523
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 7.6
# Beer = 32.4
# Total Objective Value =  843.9999999999999
# Total Barrels Made 40.0
# Corn 524
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 7.5
# Beer = 32.5
# Total Objective Value =  845.0
# Total Barrels Made 40.0
# Corn 525
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 7.4
# Beer = 32.6
# Total Objective Value =  846.0000000000001
# Total Barrels Made 40.0
# Corn 526
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 7.3
# Beer = 32.7
# Total Objective Value =  847.0
# Total Barrels Made 40.0
# Corn 527
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 7.2
# Beer = 32.8
# Total Objective Value =  848.0
# Total Barrels Made 40.0
# Corn 528
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 7.1
# Beer = 32.9
# Total Objective Value =  848.9999999999999
# Total Barrels Made 40.0
# Corn 529
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 7.0
# Beer = 33.0
# Total Objective Value =  850.0
# Total Barrels Made 40.0
# Corn 530
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 6.9
# Beer = 33.1
# Total Objective Value =  851.0000000000001
# Total Barrels Made 40.0
# Corn 531
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 6.8
# Beer = 33.2
# Total Objective Value =  852.0
# Total Barrels Made 40.0
# Corn 532
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 6.7
# Beer = 33.3
# Total Objective Value =  853.0
# Total Barrels Made 40.0
# Corn 533
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 6.6
# Beer = 33.4
# Total Objective Value =  853.9999999999999
# Total Barrels Made 40.0
# Corn 534
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 6.5
# Beer = 33.5
# Total Objective Value =  855.0
# Total Barrels Made 40.0
# Corn 535
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 6.4
# Beer = 33.6
# Total Objective Value =  856.0000000000001
# Total Barrels Made 40.0
# Corn 536
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 6.3
# Beer = 33.7
# Total Objective Value =  857.0
# Total Barrels Made 40.0
# Corn 537
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 6.2
# Beer = 33.8
# Total Objective Value =  858.0
# Total Barrels Made 40.0
# Corn 538
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 6.1
# Beer = 33.9
# Total Objective Value =  858.9999999999999
# Total Barrels Made 40.0
# Corn 539
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 6.0
# Beer = 34.0
# Total Objective Value =  860.0
# Total Barrels Made 40.0
# Corn 540
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 5.9
# Beer = 34.1
# Total Objective Value =  861.0000000000001
# Total Barrels Made 40.0
# Corn 541
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 5.8
# Beer = 34.2
# Total Objective Value =  862.0
# Total Barrels Made 40.0
# Corn 542
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 5.7
# Beer = 34.3
# Total Objective Value =  863.0
# Total Barrels Made 40.0
# Corn 543
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 5.6
# Beer = 34.4
# Total Objective Value =  863.9999999999999
# Total Barrels Made 40.0
# Corn 544
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 5.5
# Beer = 34.5
# Total Objective Value =  865.0
# Total Barrels Made 40.0
# Corn 545
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 5.4
# Beer = 34.6
# Total Objective Value =  866.0000000000001
# Total Barrels Made 40.0
# Corn 546
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 5.3
# Beer = 34.7
# Total Objective Value =  867.0
# Total Barrels Made 40.0
# Corn 547
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 5.2
# Beer = 34.8
# Total Objective Value =  868.0
# Total Barrels Made 40.0
# Corn 548
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 5.1
# Beer = 34.9
# Total Objective Value =  868.9999999999999
# Total Barrels Made 40.0
# Corn 549
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 5.0
# Beer = 35.0
# Total Objective Value =  870.0
# Total Barrels Made 40.0
# Corn 550
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 4.9
# Beer = 35.1
# Total Objective Value =  871.0000000000001
# Total Barrels Made 40.0
# Corn 551
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 4.8
# Beer = 35.2
# Total Objective Value =  872.0
# Total Barrels Made 40.0
# Corn 552
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 4.7
# Beer = 35.3
# Total Objective Value =  873.0
# Total Barrels Made 40.0
# Corn 553
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 4.6
# Beer = 35.4
# Total Objective Value =  873.9999999999999
# Total Barrels Made 40.0
# Corn 554
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 4.5
# Beer = 35.5
# Total Objective Value =  875.0
# Total Barrels Made 40.0
# Corn 555
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 4.4
# Beer = 35.6
# Total Objective Value =  876.0000000000001
# Total Barrels Made 40.0
# Corn 556
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 4.3
# Beer = 35.7
# Total Objective Value =  877.0
# Total Barrels Made 40.0
# Corn 557
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 4.2
# Beer = 35.8
# Total Objective Value =  878.0
# Total Barrels Made 40.0
# Corn 558
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 4.1
# Beer = 35.9
# Total Objective Value =  878.9999999999999
# Total Barrels Made 40.0
# Corn 559
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 4.0
# Beer = 36.0
# Total Objective Value =  880.0
# Total Barrels Made 40.0
# Corn 560
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 3.9
# Beer = 36.1
# Total Objective Value =  881.0000000000001
# Total Barrels Made 40.0
# Corn 561
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 3.8
# Beer = 36.2
# Total Objective Value =  882.0
# Total Barrels Made 40.0
# Corn 562
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 3.7
# Beer = 36.3
# Total Objective Value =  883.0
# Total Barrels Made 40.0
# Corn 563
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 3.6
# Beer = 36.4
# Total Objective Value =  883.9999999999999
# Total Barrels Made 40.0
# Corn 564
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 3.5
# Beer = 36.5
# Total Objective Value =  885.0
# Total Barrels Made 40.0
# Corn 565
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 3.4
# Beer = 36.6
# Total Objective Value =  886.0000000000001
# Total Barrels Made 40.0
# Corn 566
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 3.3
# Beer = 36.7
# Total Objective Value =  887.0
# Total Barrels Made 40.0
# Corn 567
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 3.2
# Beer = 36.8
# Total Objective Value =  888.0
# Total Barrels Made 40.0
# Corn 568
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 3.1
# Beer = 36.9
# Total Objective Value =  888.9999999999999
# Total Barrels Made 40.0
# Corn 569
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 3.0
# Beer = 37.0
# Total Objective Value =  890.0
# Total Barrels Made 40.0
# Corn 570
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 2.9
# Beer = 37.1
# Total Objective Value =  891.0000000000001
# Total Barrels Made 40.0
# Corn 571
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 2.8
# Beer = 37.2
# Total Objective Value =  892.0
# Total Barrels Made 40.0
# Corn 572
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 2.7
# Beer = 37.3
# Total Objective Value =  893.0
# Total Barrels Made 40.0
# Corn 573
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 2.6
# Beer = 37.4
# Total Objective Value =  893.9999999999999
# Total Barrels Made 40.0
# Corn 574
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 2.5
# Beer = 37.5
# Total Objective Value =  895.0
# Total Barrels Made 40.0
# Corn 575
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 2.4
# Beer = 37.6
# Total Objective Value =  896.0000000000001
# Total Barrels Made 40.0
# Corn 576
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 2.3
# Beer = 37.7
# Total Objective Value =  897.0
# Total Barrels Made 40.0
# Corn 577
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 2.2
# Beer = 37.8
# Total Objective Value =  898.0
# Total Barrels Made 40.0
# Corn 578
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 2.1
# Beer = 37.9
# Total Objective Value =  898.9999999999999
# Total Barrels Made 40.0
# Corn 579
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 2.0
# Beer = 38.0
# Total Objective Value =  900.0
# Total Barrels Made 40.0
# Corn 580
# Hops 160
# Malt 1190

# %%
# This is a simple multi Objective Version
# You are adding a second objective that disregards profits and simply maximizes total production
# Use weights to evaluate relative importance of the two objectives

for w in range(0,101):


    # Create the 'prob' variable to contain the problem data
    prob = LpProblem("Beer and Ale",LpMaximize)

    # The 2 variables Ale and Beer are created with a lower limit of 0
    A=LpVariable("Ale",0,None,LpContinuous)
    B=LpVariable("Beer",0,None, LpContinuous)


    #Weights for the different parts of the objective
    Wgt = w/100
    Wgt1 = 1-Wgt

    # The objective function is added to 'prob' first
    prob += Wgt*(25*A + 10*B) + Wgt1*(B+A), "NOTE:  We chenged the profit.  Total revenue with a factor to minimimze the extra Beer-- this only works when you know you'll make more Beer"

    # The three constraints are entered
    prob += 5*A + 15*B <= 480, "Corn"
    prob += 4*A + 4*B <= 160, "Hops"
    prob += 35*A + 20*B <= 1190, "Malt"

    # The problem data is written to an .lp file
    prob.writeLP("BeerAle.lp")

    # The problem is solved using PuLP's choice of Solver
    prob.solve()

    # The status of the solution is printed to the screen
    print("---------------------")
    print("Status:", LpStatus[prob.status])

    # Each of the variables is printed with it's resolved optimum value
    for v in prob.variables():
        print(v.name, "=", v.varValue)

    # The optimised objective function value is printed to the screen
    print("Total Objective Value = ", value(prob.objective))

    #Actual total profit.  NOTE:  The profit changed here too....
    print("Real Total Profit",25*A.varValue+10*B.varValue)  

    #Total Barrels
    print("Total Barrels Made",A.varValue+B.varValue)
    print ("Weights", Wgt, Wgt1)
# Out:
# ---------------------
# Status: Optimal
# Ale = 12.0
# Beer = 28.0
# Total Objective Value =  40.0
# Real Total Profit 580.0
# Total Barrels Made 40.0
# Weights 0.0 1.0
# ---------------------
# Status: Optimal
# Ale = 26.0
# Beer = 14.0
# Total Objective Value =  47.5
# Real Total Profit 790.0
# Total Barrels Made 40.0
# Weights 0.01 0.99
# ---------------------
# Status: Optimal
# Ale = 26.0
# Beer = 14.0
# Total Objective Value =  55.0
# Real Total Profit 790.0
# Total Barrels Made 40.0
# Weights 0.02 0.98
# ---------------------
# Status: Optimal
# Ale = 26.0
# Beer = 14.0
# Total Objective Value =  62.5
# Real Total Profit 790.0
# Total Barrels Made 40.0
# Weights 0.03 0.97
# ---------------------
# Status: Optimal
# Ale = 26.0
# Beer = 14.0
# Total Objective Value =  70.0
# Real Total Profit 790.0
# Total Barrels Made 40.0
# Weights 0.04 0.96
# ---------------------
# Status: Optimal
# Ale = 26.0
# Beer = 14.0
# Total Objective Value =  77.5
# Real Total Profit 790.0
# Total Barrels Made 40.0
# Weights 0.05 0.95
# ---------------------
# Status: Optimal
# Ale = 26.0
# Beer = 14.0
# Total Objective Value =  85.0
# Real Total Profit 790.0
# Total Barrels Made 40.0
# Weights 0.06 0.94
# ---------------------
# Status: Optimal
# Ale = 26.0
# Beer = 14.0
# Total Objective Value =  92.5
# Real Total Profit 790.0
# Total Barrels Made 40.0
# Weights 0.07 0.9299999999999999
# ---------------------
# Status: Optimal
# Ale = 26.0
# Beer = 14.0
# Total Objective Value =  100.0
# Real Total Profit 790.0
# Total Barrels Made 40.0
# Weights 0.08 0.92
# ---------------------
# Status: Optimal
# Ale = 26.0
# Beer = 14.0
# Total Objective Value =  107.5
# Real Total Profit 790.0
# Total Barrels Made 40.0
# Weights 0.09 0.91
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  115.6
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.1 0.9
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  123.76
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.11 0.89
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  131.92
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.12 0.88
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  140.08
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.13 0.87
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  148.24
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.14 0.86
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  156.39999999999998
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.15 0.85
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  164.56
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.16 0.84
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  172.72
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.17 0.83
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  180.88
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.18 0.8200000000000001
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  189.04000000000002
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.19 0.81
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  197.2
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.2 0.8
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  205.36
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.21 0.79
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  213.52
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.22 0.78
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  221.67999999999998
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.23 0.77
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  229.84
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.24 0.76
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  238.0
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.25 0.75
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  246.16
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.26 0.74
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  254.32000000000002
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.27 0.73
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  262.48
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.28 0.72
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  270.64
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.29 0.71
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  278.79999999999995
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.3 0.7
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  286.96
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.31 0.69
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  295.12
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.32 0.6799999999999999
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  303.28
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.33 0.6699999999999999
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  311.44
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.34 0.6599999999999999
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  319.6
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.35 0.65
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  327.76
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.36 0.64
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  335.92
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.37 0.63
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  344.08
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.38 0.62
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  352.24
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.39 0.61
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  360.4
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.4 0.6
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  368.56
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.41 0.5900000000000001
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  376.72
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.42 0.5800000000000001
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  384.88
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.43 0.5700000000000001
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  393.04
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.44 0.56
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  401.20000000000005
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.45 0.55
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  409.35999999999996
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.46 0.54
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  417.52
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.47 0.53
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  425.68
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.48 0.52
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  433.84
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.49 0.51
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  442.0
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.5 0.5
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  450.16
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.51 0.49
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  458.32
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.52 0.48
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  466.48
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.53 0.47
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  474.64000000000004
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.54 0.45999999999999996
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  482.8
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.55 0.44999999999999996
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  490.96000000000004
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.56 0.43999999999999995
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  499.11999999999995
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.57 0.43000000000000005
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  507.2799999999999
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.58 0.42000000000000004
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  515.44
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.59 0.41000000000000003
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  523.6
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.6 0.4
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  531.76
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.61 0.39
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  539.9200000000001
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.62 0.38
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  548.08
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.63 0.37
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  556.24
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.64 0.36
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  564.4000000000001
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.65 0.35
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  572.56
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.66 0.33999999999999997
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  580.7199999999999
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.67 0.32999999999999996
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  588.88
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.68 0.31999999999999995
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  597.04
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.69 0.31000000000000005
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  605.2
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.7 0.30000000000000004
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  613.36
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.71 0.29000000000000004
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  621.52
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.72 0.28
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  629.68
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.73 0.27
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  637.84
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.74 0.26
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  646.0
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.75 0.25
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  654.16
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.76 0.24
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  662.32
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.77 0.22999999999999998
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  670.48
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.78 0.21999999999999997
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  678.64
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.79 0.20999999999999996
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  686.8
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.8 0.19999999999999996
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  694.96
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.81 0.18999999999999995
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  703.12
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.82 0.18000000000000005
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  711.2800000000001
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.83 0.17000000000000004
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  719.44
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.84 0.16000000000000003
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  727.5999999999999
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.85 0.15000000000000002
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  735.76
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.86 0.14
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  743.92
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.87 0.13
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  752.08
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.88 0.12
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  760.24
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.89 0.10999999999999999
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  768.4000000000001
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.9 0.09999999999999998
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  776.56
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.91 0.08999999999999997
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  784.7199999999999
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.92 0.07999999999999996
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  792.88
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.93 0.06999999999999995
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  801.04
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.94 0.06000000000000005
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  809.2
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.95 0.050000000000000044
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  817.36
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.96 0.040000000000000036
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  825.52
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.97 0.030000000000000027
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  833.68
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.98 0.020000000000000018
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  841.84
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.99 0.010000000000000009
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  850.0
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 1.0 0.0
